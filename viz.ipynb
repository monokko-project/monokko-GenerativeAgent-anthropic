# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# read csv file

df = pd.read_csv('out/agent_1.csv')
plt.title('the emotion of book-n')
ax = sns.lineplot(data=df)
plt.show()

# %%
df = pd.read_csv('out/agent_2.csv')
plt.title('the emotion of pen-chan')
ax = sns.lineplot(data=df)
plt.show()
